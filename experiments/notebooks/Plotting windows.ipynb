# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import os
import sys
import warnings
warnings.filterwarnings('ignore')

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
base = '..'

# %%
from ae.utils import plot_windows

plot_windows('ENCSR320PGJ', num=10, min_signal=3, base=base)
# Out:
# (array([2699, 4819, 5048, 4740, 2053, 5631, 1788, 3394, 1931,  413]),
#  array([ 3.14110699,  7.5009665 , 12.59587191, 16.75001286, 10.75691069,
#          8.13727656,  5.22009628,  3.91867413,  6.98543393,  3.46012562]),
#  array([0.22085899, 1.        , 1.        , 1.        , 0.94248493,
#         0.99233129, 0.17944795, 0.43118436, 1.        , 0.26073637]))

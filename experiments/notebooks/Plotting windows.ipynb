# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import os
import sys
import warnings
warnings.filterwarnings('ignore')

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
base = '..'

# %%
from ae.utils import plot_windows

plot_windows('merged', ds_type='test', num=20, min_signal=3, base=base)
# Out:
# (array([ 177, 1405, 1320, 1112, 1061,  184, 1177, 1490,  982,  753,  215,
#         1629,  671, 1507,  601,  296,  853,  779, 1561, 1661]),
#  array([ 4.70939328,  5.43002467,  5.76035759, 12.15650053,  5.9264978 ,
#          3.25694842, 19.13295392, 14.03171629,  3.28253004,  3.19969651,
#          6.91666801,  6.67461182,  6.35462631,  6.63252677,  3.71014997,
#          3.00918974,  4.27119041, 13.37327503,  5.64902888, 11.22233452]),
#  array([0.46322823, 0.19407537, 0.54339253, 0.51113727, 0.12293929,
#         0.17162713, 1.        , 1.        , 0.20691677, 0.69189864,
#         1.        , 0.23611131, 0.42438439, 1.        , 0.16290536,
#         0.29673103, 0.18947885, 1.        , 1.        , 1.        ]))

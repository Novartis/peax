# %% [markdown]
# # ENCODE DNase 3 kb Final

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import h5py
import json
import numpy as np
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
# The base directory is one level up
base = '..'
size = '3kb'
name = 'encode-dnase-{}-init'.format(size)
settings_filepath = 'settings-encode-dnase-{}.json'.format(size)
search_name = 'cnn-final'
search_filepath = '{}.json'.format(search_name)
datasets_filepath = 'datasets-grch38-dnase-2019-02-16-half.json'

with open(os.path.join(base, settings_filepath), "r") as f:
    settings = json.load(f)

with open(os.path.join(base, search_filepath), "r") as f:
    search = json.load(f)
    
dataset = 'encode-dnase_w-{}_f-{}_r-{}-2019-02-16-half'.format(
    settings['window_size'],
    settings['step_frequency'],
    settings['resolution'],
)

with h5py.File(os.path.join(base, 'data', '{}.h5'.format(dataset)), 'r') as f:
    print()
    print('Dataset: {}'.format(dataset))
    print('Training samples: {}'.format(f['data_train'].shape[0]),)
    print('Dev samples: {}'.format(f['data_dev'].shape[0]))
    print('Test samples: {}'.format(f['data_test'].shape[0]))
    print('---')
    print('Total samples: {}'.format(f['data_train'].shape[0] + f['data_dev'].shape[0] + f['data_test'].shape[0]))
# Out:
# Dataset: encode-dnase_w-3000_f-2_r-25-2019-02-16-half
# Training samples: 30872061
# Dev samples: 2724009
# Test samples: 2724041
# ---
# Total samples: 36320111

# %%
import h5py

dtype = 'data_train'

with h5py.File(os.path.join(base, 'data', '{}.h5'.format(dataset)), 'r+') as f:
    N = f[dtype].shape[0]
    
    isnan = np.isnan(f[dtype])
    
    ids = np.arange(N)[np.sum(isnan, axis=1).squeeze().astype(np.bool)]
    
    print("{} our of {} windows in {} have nans".format(ids.size, N, dtype))
    
    for idx in ids:
        d = f[dtype][idx]
        d[np.where(np.isnan(d))] = 0
        f[dtype][idx] = d

# %% [markdown]
# ## Prepare data

# %%
from prepare import prepare_jobs

prepare_jobs(
    'DNase',
    datasets_filepath,
    settings_filepath,
    base=base,
    clear=False,
    verbose=False,
)

# %% [markdown]
# Run `sbatch prepare.slurm`

# %%
"""Check if all datasets have been prepared"""

import h5py

try:
    with open(os.path.join(base, datasets_filepath), "r") as f:
        all_datasets = json.load(f).keys()
except FileNotFoundError:
    all_datasets = []
    print("Damn! Where is the file with the ENCODE experiments?")

not_found = []
outdated = []
total_size = 0

for dataset in all_datasets:
    filepath = os.path.join(
        base,
        'data',
        '{}_w-{}_f-{}_r-{}.h5'.format(
            dataset,
            settings["window_size"],
            settings["step_frequency"],
            settings["resolution"]
        )
    )
    total_size += os.path.getsize(filepath)
    try:
        with h5py.File(filepath, "r") as f:
            try:
                print('Train: {} ({}) Dev: {} ({}) Test: {} ({})'.format(
                    f['data_train'].shape[0],
                    f['peaks_train'].shape[0],
                    f['data_dev'].shape[0],
                    f['peaks_dev'].shape[0],
                    f['data_test'].shape[0],
                    f['peaks_test'].shape[0],
                ))
                x = f['data_train']
                x = f['data_dev']
                x = f['data_test']
                x = f['peaks_train']
                x = f['peaks_dev']
                x = f['peaks_test']
                x = f['shuffling']
                x = f['settings']
            except KeyError:
                outdated.append(dataset)
    except OSError:
        not_found.append(dataset)

print("{} are not found".format(len(not_found)))
print("{} are not outdated".format(len(outdated)))

# %% [markdown]
# #### Check data for nan values

# %%
import h5py

nans = 0

with h5py.File(os.path.join(base, 'data', '{}.h5'.format(dataset)), 'r') as f:
    N = f[dtype].shape[0]
    
    isnan_train = np.isnan(f['data_train'])
    isnan_dev = np.isnan(f['data_dev'])
    isnan_test = np.isnan(f['data_test'])
    
    nans = np.sum(isnan_train) + np.sum(isnan_dev) + np.sum(isnan_test)

print('Found {} nans in total'.format(nans))

# %% [markdown]
# ## Merge data
#
# Run `sbatch merge-dnase-3kb-half.slurm` and `sbatch merge-dnase-3kb.slurm`

# %% [markdown]
# ## Create training jobs

# %%
from jobs import jobs

jobs(
    search_filepath,
    settings_filepath,
    dataset=dataset,
    name=name,
    cluster='seasdgx1',
    epochs=5,
    batch_size=256,
    repeat=3,
    base=base,
    clear=True,
    verbose=False
)
# Out:
# HBox(children=(IntProgress(value=0, description='Jobs', max=1, style=ProgressStyle(description_width='initial'…
# Created slurm file for training 1 neural networks

# %%
from ae.utils import check_status

okay, not_found, outdated = check_status(
    search_name, 'training', dataset, base=base
)

if okay:
    print('Trainings completed')
else:
    print('Trainings did not finish. Missing {}'.format(len(not_found)))
# Out:
# Trainings completed

# %% [markdown]
# ## Create evaluation jobs

# %%
from evaluate import create_jobs

create_jobs(
    search_name,
    name=name,
    dataset=dataset,
    cluster='seasdgx1',
    base=base,
    incl_dtw=False,
)
# Out:
# Created slurm file for evaluating 3 neural networks

# %% [markdown]
# In a terminal run: `sbatch evaluate-cnn-final-test.slurm`

# %%
from ae.utils import check_status

okay, not_found, outdated = check_status(
    search_name, 'evaluation', dataset, base=base
)

if okay:
    print('Evaluation completed')
else:
    print('Evaluation did not finish. Missing {}'.format(len(not_found)))
# Out:
# Evaluation completed

# %% [markdown]
# ## Compare

# %%
from compare import compare
    
performance = compare(
    'definitions-{}.json'.format(search_name),
    dataset_name=dataset,
    base=base,
    clear=False,
    verbose=False,
    silent=False,
    remove_common_prefix_from_df=True,
)
# Out:
# num_models 3

# %%
import qgrid

qgw = qgrid.show_grid(performance)
qgw
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
from IPython.core.display import Image, display
from itertools import takewhile


with open(os.path.join(base, 'definitions-{}.json'.format(search_name)), 'r') as f:
    definitions = json.load(f)

lcp = ''.join(c[0] for c in takewhile(lambda x: all(x[0] == y for y in x), zip(*definitions)))

for model in qgw.get_selected_df().iterrows():
    model_name, repetition = (lcp + model[0]).split('__')
    print('Repetition #{}'.format(repetition))
    display(Image(os.path.join(base, 'models', '{}---predictions-{}__{}.png'.format(model_name, dataset, repetition))))
# Out:
# Repetition #1
# Repetition #2
# Repetition #0

# %% [markdown]
# ---
# ---
# ---
#
# # Re-train
#
# Run `sbatch train-encode-dnase-3kb-retrain.slurm`

# %%
from ae.utils import check_status

model_name='cf-128-192-288-432--ck-3-5-7-9--du-1024-256--do-0-0-0-0-0-0--e-10--rl-0--o-adadelta--lr-1.0--lrd-0.001--l-bce--m---bn-0-0-0-0-0-0--bni-0--pw-8--sw-logn--swz-0.0'

okay, not_found, outdated = check_status(
    search_name,
    'training',
    dataset=dataset,
    base=base,
    re_trained=True,
    model_name=model_name
)

if okay:
    print('Training completed')
else:
    print('Training did not finish. Missing {}'.format(len(not_found)))
    print(not_found)
# Out:
# Training completed

# %% [markdown]
# ## Evaluation
#
# Run `sbatch evaluate-encode-dnase-3kb-retrain.slurm`

# %%
from ae.utils import check_status

model_name='cf-128-192-288-432--ck-3-5-7-9--du-1024-256--do-0-0-0-0-0-0--e-10--rl-0--o-adadelta--lr-1.0--lrd-0.001--l-bce--m---bn-0-0-0-0-0-0--bni-0--pw-8--sw-logn--swz-0.0'

okay, not_found, outdated = check_status(
    search_name,
    'evaluation',
    dataset=dataset,
    base=base,
    re_trained=True,
    model_name=model_name
)

if okay:
    print('Evaluation completed')
else:
    print('Evaluation did not finish. Missing {}'.format(len(not_found)))
    print(not_found)
# Out:
# Evaluation completed

# %%
import h5py
from IPython.core.display import Image, display

with h5py.File(os.path.join(base, 'models', '{}---evaluation-{}-re-trained.h5'.format(model_name, dataset)), 'r') as f:
    print(np.mean(f['total_loss'], axis=0))
    print(f['total_times'][:])

display(Image(os.path.join(base, 'models', '{}---predictions-{}-re-trained.png'.format(model_name, dataset))))
# Out:
# [0.02413052 0.01982735 0.09152179]
# [[4783.54076123 4778.47105265 4729.18904257 4901.11390209]]

# %%
from train import plot_loss_to_file

with h5py.File(os.path.join(base, "models", "{}---training-{}-re-trained.h5".format(model_name, dataset)), "r") as f:
    plot_loss_to_file(
        f['loss'][:],
        f['val_loss'][:],
        model_name,
        dataset_name=dataset,
        title="Training on DNase-seq windows of 3 kilobase pairs",
        base=base,
    )

# %%
from ae.utils import plot_windows

plot_windows(
    dataset,
    model_name='cf-128-192-288-432--ck-3-5-7-9--du-1024-256--do-0-0-0-0-0-0--e-10--rl-0--o-adadelta--lr-1.0--lrd-0.001--l-bce--m---bn-0-0-0-0-0-0--bni-0--pw-8--sw-logn--swz-0.0',
    ds_type="test",
    window_ids=[15642, 505794, 55716],
    base=base,
    trained_on_single_dataset=True,
    re_trained=True,
    no_legend=True,
    no_peak_coloring=True,
    diff=True,
    plot_reconst_separately=True,
    no_title=True
)
# Out:
# /n/pfister_lab/haehn/ENVS/peax/lib/python3.6/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# (array([ 15642, 505794,  55716]),
#  array([ 8.43738109, 45.44632806, 62.8910504 ]),
#  array([0.34018654, 1.        , 0.94999945]))
